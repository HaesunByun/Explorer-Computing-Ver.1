# %% [markdown]
# ---
# <font color='Blue' size="4">
# F37.206 컴퓨팅 탐색: 실생활에서 활용하기(Exploring Computing: Applications in Everyday Life)</font>
#
# ---

# %% [markdown]
# # Chapter 12. 실시간 정보 수집 자동화

# %% [markdown]
# <div style="background-color: #f5fff5; padding: 10px; border-radius: 5px; color: #000000;">
#
# <font size=5> <strong> <mark style="background-color: #f5fff5;">✅ 학습목표와 기대효과 </mark></strong></font>
#
# <mark style="background-color: #f5fff5;">
# 🔹 학습목표<br>
#   <ul><li> BeautifulSoup모듈에 대해서 알아보자.</li>
#   <li> 웹드라이버를 활용하여 웹페이지를 크롤링 해보자.</li>
#   <li> 크롤링을 지원하는 중요한 메서드들을 알아보자.</li></ul>
# 🔹 기대효과<br>
#   <ul><li> 웹 크롤링에 필요한 핵심 모듈과 메서드를 이해하여 원하는 정보를 자동으로 수집할 수 있다.</li>
#   <li>실습을 통해 웹데이터를 활용한 자동화와 데이터 분석의 기초 역량을 향상시킨다.</li></ul></mark>
# </div>

# %% [markdown]
# ## <div style="background-color:rgba(208, 205, 208, 1); padding: 10px; border-radius: 5px;"><mark style="background-color: rgba(208, 205, 208, 1);">**웹(www)과 HTML**</mark></div>
#
# - 웹주소를 보면 보통 시작이 www이다. www는 world wide web의 약자로 web이 거미줄이라는 뜻을 가지고 있어서 전 세계로 퍼진 거미줄로 직역할 수 있다.
# - 웹에서 보여지는 페이지(문서)를 웹페이지라고 하며, 웹페이지를 만드는데 사용되는 언어중 하나가 바로 `HTML`(HyperText Markup Language)이다.
# - `HTML`은 웹페이지가 어떻게 구조화되어 있는지를 웹브라우저(크롬, 익스플로러, 엣지, 사파리 등)가 인식하도록 하는 언어이다.

# %% [markdown]
# ### 태그(tag)
# - HTML로 작성된 페이지는 다양한 `태그`(tag)로 구성되어 있다.
# - 태그는 웹페이지의 구조와 내용을 정의하는 기본 단위로, 문서의 제목, 단락, 이미지, 링크 등 다양한 요소를 표현하고 구성하는 역할을 한다.
# - 태그에는 여는(opening) 태그와 닫는(closing) 태그가 있다.
# - 여는 태그와 닫는 태그 사이에는 내용(content)이 들어간다.
#     ```html
#     <여는 태그> 내용 </닫는 태그>
# - 예를 들어, 아래 코드에서 여는 태그는 `<p>`, 닫는 태그는 `</p>`, 내용은 `아름다운 날이에요.`가 된다.
#     ```html
#     <p> 아름다운 날이에요. </p>
# - 여는 태그, 닫는 태그, 내용을 통틀어 요소(element)라고 한다.
# ---

# %% [markdown]
# - 아래 중첩된 태그로 구성된 매우 간단한 HTML문서를 살펴보자.
#
#   ```html
#   <!DOCTYPE html >
#   <html>
#     <head>
#       <title> This is my page </title>
#     </head>
#     <body>
#       <p>아름다운 날이에요.</p>
#     </body>
#   </html >
#   ```

# %% [markdown]
# - 이 HTML문서를 웹브라우저에서 열면 아래와 같이 `아름다운 날이에요.` 한 줄만 보여진다.
#
# <div align="center"><img src="https://haesunbyun.github.io/common/images/html1.png" style="width:600px;"></div>

# %% [markdown]
# - HTML 문서는 `<!DOCTYPE html>` 태그로 시작한다. 이 태그는 문서의 타입을 정의하는 태그로 이 페이지가 html로 구성된 문서임을 웹브라우저가 알게 한다.
# - 그 이후 여는 태그 `<html>`로 열고, 끝은 닫는 태그 `</html>`로 닫는다. `<html> ~ </html>`는 전체 페이지의 컨텐츠를 포함하는 기본 요소이다.
# - `<html> ~ </html>` 태그 사이에는 크게 `<head> ~ </head>` 태그와 `<body> ~ </body>`태그로 구성된다.
#   - `<head> ~ </head>` 태그 안에는 웹페이지의 인코딩 방식, 웹페이지의 제목, CSS(Cascading Stylesheets)의 링크, 그 밖의 부가정보(작성자, 중요 키워드)를 포함한다. 그러나 이러한 정보들은 웹페이지의 제목을 제외하고는 웹 브라우저에 표시되지 않는다.
#   - `<body>~</body>` 태그 안에는 텍스트, 이미지, 비디오, 게임, 재생 가능한 오디오 트랙 등을 비롯하여 `웹페이지에 표시되는 모든 콘텐츠`가 들어간다.
#   ---

# %% [markdown]
# - 태그 안에는 또 다른 태그가 중첩되기도 한다.
# - 한 예로, 아래에서  `<p> ~ </p>` 태그 사이에 `<strong> ~ </strong>` 태그가 중첩되어 있다. 참고로 `<p>` 태그는 paragraph를 의미하며, `<strong>`은 진하게 나타내라는 의미이다.
#     ```html
#     <p> 수강취소 안하고 여기까지 온 <strong> 당신 매우 멋지십니다.</strong> </p>
#
# - 웹페이지에서 보여지는 결과는 다음과 같다.
#     <p> 수강취소 안하고 여기까지 온 <strong> 당신 매우 멋지십니다.</strong> </p>
# ---

# %% [markdown]
# - 또한, 일부 태그는 여는 태그만 있고, 닫는 태그가 없는 단일 태그(Single tag) 형태도 있다.
# - 한 예로, `<img>` 태그는 이미지를 보여주기 위한 태그로 여는 태그만 있다.
#     ```html
#     <img src="https://haesunbyun.github.io/common/images/html2.png">
#
# - 웹페이지에서 보여지는 결과는 다음과 같다.
#
#     <img src="https://haesunbyun.github.io/common/images/html2.png">

# %% [markdown]
# ### 속성(attribute)
# - 여는 태그안에는 하나 이상의 `속성`을 넣을 수 있다.
# - 속성은 요소에 추가적인 성질, 링크, 내용 등을 포함시키고 싶을 때 사용하며 실제 웹페이지에 보이지는 않는다.
# - 속성을 주는 형식은 다음과 같다.
#     ```html
#     < 여는 태그 속성명="속성값" 속성명="속성값" ...>
#
# - 예를 보자.
#     ```html
#     <img src="https://haesunbyun.github.io/common/images/html2.png">
#     <p class="editor-note"> 안녕하세요.</p>
#     <p> 여기는 <a href="https://www.snu.ac.kr/" title="서울대학교 홈페이지">서울대학교</a>입니다.</p>
# - 위의 html에서 img 태그의 `src`, p 태그의 `class`, a 태그의 `href`, `title` 이 속성명이다.
# - `"editor-note", "https://www.snu.ac.kr/", "서울대학교 홈페이지"`는 속성 값이다.

# %% [markdown]
# - 웹페이지에서 보여지는 결과는 아래와 같다. 속성이 많지만 웹에서는 보이지 않는다.
#
#     <img src="https://haesunbyun.github.io/common/images/html2.png">
#     <p class="editor-note"> 안녕하세요.</p>
#     <p> 여기는 <a href="https://www.snu.ac.kr/" title="서울대학교 홈페이지">서울대학교</a>입니다.</p>

# %% [markdown]
# - 미리 말하지만, 크롤링을 하기 위해 모든 태그를 알아야 하는 것은 아니니 걱정하지 않아도 된다.
# - 우리는 이미 Streamlit으로 웹을 만들어 보았고, 그때 태그를 몰라도 충분히 웹을 구현할 수 있었다.
# - 마찬가지로 이번 학습의 목적은 웹 구조를 이해하고 필요한 정보를 추출하는 것이므로, 태그를 외우거나 전부 이해할 필요는 없다.

# %% [markdown]
# ## <div style="background-color:rgba(208, 205, 208, 1); padding: 10px; border-radius: 5px;"><mark style="background-color: rgba(208, 205, 208, 1);">**웹크롤링과 웹스크랩핑**</mark></div>
#
# - 식상한 표현이지만 웹은 무한히 많은 데이터가 있는 정보의 바다이다. 이러한 웹에서 유의미한 데이터를 찾는 것은 매우 중요한 일이 됐다.
# - 웹 페이지에서 정보를 추출하는 프로그램을 웹크롤러(Web Crawler), 또는 스파이더(Spider), 봇(Bot)이라고도 부르며, 웹크롤러를 사용하여 데이터를 수집하는 것을 웹크롤링(Web Crawling)이라고 하다.
# - 즉, 웹크롤링은 웹페이지의 하이퍼링크를 순회하면서 웹 페이지를 다운로드 하는 작업을 의미한다.
# - 웹스크랩핑(Scraping)은 다운로드한 웹 페이지에서 필요한 정보를 추출하는 작업을 의미한다.
# - 일부 모듈들은 웹크롤링과 웹스크랩핑 기능을 모두 갖고 있기도 해서 이를 혼용하여 부르기도 한다.

# %% [markdown]
# - 웹크롤링은 다양하게 활용되고 있다.
#   - 음식점의 예약 상황을 실시간으로 추출하여 어떤 음식점에 자리가 비어있는지, 어떤 요일과 어떤 시간에 어떤 음식점이 인기 있는지 등의 정보를 추출하는데 활용되기도 한다.
#   - 여러 책 판매 사이트에서 정보를 추출하여 직접 가격 비교해서 최저가 정보를 알려주거나 웹사이트에서 정보를 추출하고 정보를 정리하는데 사용되기도 한다.
#   - 정부, 자치단체, 기업 등이 자유롭게 사용할 수 있도록 공개한 데이터인 열린 데이터를 수집할 때도 도움이 된다.
#   - 웹데이터 분석, 자연언어분석, 이미지 처리 등 대량의 데이터 수집이 필요 할 때도 이용된다.

# %% [markdown]
# - 파이썬 언어를 통해 웹 크롤링을 하는 데 사용하는 모듈에는
#   - urllib.request: HTTP 요청을 보낼 수 있는 표준 라이브러리
#   - requests: 더 간단한 HTTP 요청용 외부 라이브러리
#   - BeautifulSoup: HTML 파싱(문서 구조 분석)용
#   - Selenium: 브라우저 자동화 및 동적 웹 페이지 크롤링용 등이 있다.
#
# - 웹 스크레이핑(Scraping)을 수행하는 주요 방법에는
#   - re 모듈을 이용한 정규표현식 추출,
#   - XPath나 CSS 선택자를 이용한 요소 지정,
#   - BeautifulSoup 모듈,
#   - Selenium 모듈 등이 있다.

# %% [markdown]
# ### 1. urlopen()으로 웹페이지 가져오기
# - 웹크롤링을 하기 위해서는 먼저 웹페이지에 접속부터 해야 한다.
# - 파이썬으로 웹페이지에 접속하기 위해서는 urllib.request 모듈의 urlopen() 함수를 통해 할 수 있다.
#   - urllib 패키지는 URL과 관련된 작업을 하기 위한 여러 모듈을 모은 패키지로, 그중에서 urllib.request 모듈은 URL을 여는것과 관련한 다양한 함수를 제공하고 있다.
# - 이번 시간에 우리가 접속하여 크롤링할 사이트는 우리 강좌의 강의자료가 들어있는 웹페이지이다.
# https://haesunbyun.github.io/Explorer-Computing-Ver.1/intro.html
# - 먼저, urlopen() 함수를 import하고, urlopen() 괄호안에 접속할 사이트의 주소를 넣어준다.

# %%
from urllib.request import urlopen
page = urlopen('https://haesunbyun.github.io/Explorer-Computing-Ver.1/intro.html')
print(page)

# %% [markdown]
# - 변수 page를 출력해보면, 에러없이 웹페이지를 열었지만 반환된 값은 웹문서 스타일이 아니라 HTTPResponse 객체이다.

# %% [markdown]
# ### 2. BeautifulSoup()으로 웹스크랩핑하기
# - urlopen()으로 가져온 웹페이지를 눈으로 확인 가능한 HTML문서로 바꿔보자.
# - 이를 위해 BeautifulSoup()를 활용할 수 있다.
# - BeautifulSoup() 함수는 HTML에서 데이터를 추출할 수 있도록 하는 함수로 HTML 구문 분석 기능을 갖고 있다.
#     - 참고자료: https://www.crummy.com/software/BeautifulSoup/bs4/doc/

# %% [markdown]
# - 먼저 bs4모듈에 BeautifulSoup()를 import한다.
# - BeautifulSoup() 함수의 괄호안에는 첫 번째 전달인자로 구문을 분석하고자 하는 HTML, 두 번째 전달인자로 분석할 파서의 종류를 넣어준다. 여기서는 html 구문으로 파싱할 것이므로 'html.parser'로 적어준다.
# - 파싱(parsing)이란 `구문 분석`이라는 뜻으로 각 구성 성분으로 분해하고 이들간의 관계를 분석하여 구조를 결정하는 작업을 말한다.
# - 파싱하여 변수 soup에 저장하여 출력해보면 urlopen()으로 가져왔던 웹페이지가 html코드로 보여진다.
#   - 통상적으로 BeautifulSoup()으로 파싱한 객체는 변수 이름을 soup으로 한다.
# - 변수 soup에는 웹페이지의 소스코드가 들어있으며, 그 안에 우리가 수집하려고하는 정보도 함께 들어있다.
# - 이제 보물찾기를 해야 한다.

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(page,'html.parser')
print(soup)

# %% [markdown]
# ### 3. 엘리먼트 검색에 개발자 도구 활용하기

# %% [markdown]
# - 추출하려는 데이터가 `F37.206 컴퓨팅 탐색: 실생활에서 활용하기`이라고 해보자.
# - 엘리먼트를 찾기 위해서는 HTML 문서를 살펴봐야 하지만, HTML 문서는 태그가 많고 중첩 구조가 복잡하여 전체 구조를 한눈에 파악하기 어렵다.
# - 이때 엘리먼트를 쉽게 찾을 수 있도록 도와주는 도구가 바로 개발자 도구이다.
# - 개발자 도구는 웹페이지의 구조를 한눈에 파악할 수 있도록 보여준다.
# - 개발자 도구를 활용하면 추출하려는 엘리먼트가 어떤 태그에 위치하며, 어떤 속성을 가지고 있는지를 쉽게 확인할 수 있다.
# - 개발자 도구는 브라우저에서 일반적으로 `오른쪽 상단에 (⋮)를 클릭하여 도구 더보기 > 개발자 도구`를 클릭하면 보인다.
# - 단축키는 F12 또는 Ctrl+Shift+I이다.
# <div align="center"><img src="https://haesunbyun.github.io/common/images/comps/web1.png" width="500",></div>

# %% [markdown]
# - 개발자 도구를 열면 HTML 구조를 보여주는 엘리먼트 창이 나타나고, 이를 통해 웹페이지의 소스코드를 구조적으로 볼 수 있다.
# - 소스코드 창 왼쪽 상단에 `화살표 모양의 요소(element) 선택 버튼`을 클릭한다.
# - 엘리먼트 선택 버튼은 현재 로딩된 웹페이지의 엘리먼트를 선택하는 버튼이다.
# - 엘리먼트 선택 버튼을 누른 후, 웹페이지의 컨텐츠로 마우스를 가져가면 해당 요소의 상세 정보(태그 정보, CSS 정보)를 확인할 수 있다.
# - 또한 컨텐츠를 클릭하면 해당 엘리먼트의 소스코드(HTML)가 있는 위치로 바로 이동시켜주는 기능을 제공한다.
# - 마우스를 이동시킬 때마다 소스보기에서도 음영처리된 부분이 바뀌는 것을 볼 수 있을 것이다.
# <div align="center"><img src="https://haesunbyun.github.io/common/images/comps/image59.png" width="500"></div>

# %% [markdown]
# #### 3.1 태그와 속성 확인
# - 개발자 도구를 활용하여 수집하려고 하는 텍스트가 있는 엘리먼트의 태그와 속성을 확인한다.
# - 우리가 찾고자 하는 엘리먼트는 `<p>F37.206 컴퓨팅 탐색: 실생활에서 활용하기</p>`이다. 즉 `<p>`태그에 들어있다.

# %% [markdown]
# #### 3.2 태그로 찾기
# - `<p>`태그에 들어있다는 것을 확인했으니 다시 코드로 돌아와 변수 soup에서 `<p>`태그로 수집하려는 정보를 추출해야 한다.
# - BeautifulSoup의 태그나 속성으로 수집하려는 정보를 찾을 수 있도록 find()와 find_all() 메서드를 지원한다.
#     ```
#     soup.find('tag명'): 가장 처음에 있는 <tag명> 하나만 반환
#     soup.find_all('tag명'): <tag명>을 모두 찾아내어 리스트와 비슷한 형태로 반환.
#     ```

# %% [markdown]
# - 먼저, find() 메서드를 사용해보자.
# - find()는 하나의 엘리먼트만 찾는 경우 유용하다.

# %% [markdown]
# - 이번에는 find_all()로 찾아보자.

# %% [markdown]
# - find_all()의 결과는 'bs4.element.ResultSet'이다. 리스트는 아니지만 리스트처럼 보여지며, 리스트와 같이 접근이 가능하다.

# %% [markdown]
# - 우리가 추출하려는 `F37.206 컴퓨팅 탐색: 실생활에서 활용하기`는 인덱스 4에 있다.

# %% [markdown]
# #### 3.3 텍스트 추출하기
# - 추출하려는 데이터가 있는 태그까지 접근했다면 텍스트를 추출해보자.
# - 텍스트를 추출하는 방법은 다음과 같다.
#   - get_text(): 현재 태그를 포함하여 모든 하위 태그에 있는 텍스트를 추출한다.
#     - 괄호안에 별도의 옵션을 줄 수 있다. 예) strip=True
#   - text: 현재 태그를 포함하여 모든 하위 태그에 있는 텍스트를 추출한다.
#   - string: 태그에 컨텐츠가 하나인 경우만 추출가능하다.
# - get_text()와 text는 정확히 동일한 결과를 반환한다. 차이점이 있다면 get_text()의 경우 괄호안에 별도의 옵션을 줄 수 있다는 것이다. 예) get_text(strip=True)

# %% [markdown]
# - 'bs4.element.ResultSet'은 반복가능한 데이터셋이다.
# - 즉, 리스트처럼 반복문에서 활용할 수 있다.

# %% [markdown]
# #### 3.4 속성으로 찾기
# - find()나 find_all()함수에서 전달인자로 태그 안에 있는 속성명이나 속성값을 함께 지정하여 찾을 수도 있다.
# - 즉, 검색 조건을 여러개 지정하면 찾고자 하는 데이터에 더 근접하여 추출할 수 있다.
# - 태그명없이 속성으로만 찾을 수도 있다.
#     ```
#     soup.find('tag명', 속성명='속성값')
#     soup.find_all(속성명='속성값')
#     ```

# %% [markdown]
# - 이번에는 모든 chapter의 제목을 추출해보자.
# - 개발자도구를 활용하여 chapter 제목이 어떤 태그와 어떤 속성을 가지고 있는지 확인한다.

# %%
chap_list = soup.find_all('태그명을 넣어주세요.', class_='속명값을 채워주세요.')

# %% [markdown]
# - 반복문을 활용하여 모든 a 태그의 텍스트를 추출해보자.

# %% [markdown]
# #### 3.5 속성값 추출하기
# - 어떤 경우에는 속성값을 추출해야 할 필요가 있기도 하다.  대표적인 예로 링크주소를 추출하고 싶을 때가 그렇다.
# - 이럴 때에는 속성명을 활용하여 속성값을 추출하면 된다.
# - 속성값을 추출할 때에는 태그 뒤 대괄호[ ] 안에  속성명을 문자열로 넣어주면 된다.
# ```
# soup.find('태그')['속성명']
# ```

# %% [markdown]
# - 태그로 직접 접근해 속성값을 추출할 수 있다. 마치 딕셔너리의 키를 통해 값에 접근할 수 있는 것처럼 속성명은 키, 속성값은 값이라고 보면 된다.

# %% [markdown]
# - 반복문을 활용하여 모든 a 태그의 링크주소를 추출해보자.

# %%
for each in chap_list:
    print(each['href'])

# %% [markdown]
# - 추출한 데이터를 딕셔너리로 만들어보자.

# %%
chap_dict=dict()
for each in chap_list:
    chap_dict[each.text] = 'https://haesunbyun.github.io/Explorer-Computing-Ver.1/'+each['href']

chap_dict

# %% [markdown]
# - 만들어진 딕셔너리에서 불필요한 아이템은 삭제하자.

# %% [markdown]
# ## <div style="background-color:rgba(208, 205, 208, 1); padding: 10px; border-radius: 5px;"><mark style="background-color: rgba(208, 205, 208, 1);">**스트림릿으로 웹크롤링하기**</mark></div>

# %% [markdown]
# - 이번에는 Streamlit 웹 앱에서 사용자가 검색어를 입력하면, 해당 검색어를 이용해 웹 크롤링이 이루어지도록 만들어보자.
# - 크롤링 대상은 네이버 검색 엔진을 활용하도록 한다.

# %%
# %%writefile Ex_ch12_web.py
import streamlit as st
import requests
from bs4 import BeautifulSoup
import time

# 제목
st.title("네이버 검색 결과 크롤링")

# 검색어 입력
query = st.text_input("검색어를 입력하세요")

if query:
    # URL
    url = f"https://search.naver.com/search.naver?query={query}"

    # 헤더 설정 (User-Agent 필수)
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"
    }

    # requests모듈의 get()함수를 이용하여 웹크롤링, urlopen(url)과 비슷
    response = requests.get(url, headers=headers)    
    time.sleep(1)
    if response.status_code == 200: #정상적으로 웹페이지를 받았을때 코드가 200임
        soup = BeautifulSoup(response.text, "html.parser")

        st.subheader(f"'{query}' 검색 결과")

        find_items = soup.find_all('여기에 검색할 태그와 속성을 입력해주세요.')
        if find_items:
            st.write(f"{len(find_items)}개 찾았습니다.")
            for item in find_items:
                # 아래 item.span.text 부분은 해당 태그를 확인하여 텍스트를 추출
                st.write(item.span.text, item.a['href'])
        else:
            st.write("검색 결과가 없습니다.")
    else:
        st.error("검색에 실패했습니다.")

# %% [markdown]
# :::참고
# - headers: header 정보를 넣지 않으면 봇이라고 인식하여 네이버 같은 사이트는 접근이 막히거나 정상 HTML을 못 받는 경우가 많음
#     - Mozilla/5.0 → 전통적으로 브라우저 타입 표시
#     - (Windows NT 10.0; Win64; x64) → OS 정보
#     - Chrome/142.0.0.0 → 브라우저 정보
#     - AppleWebKit/537.36 → 브라우저 엔진 정보
# - 즉, 서버 입장에서는 `Windows 10에서 Chrome 브라우저가 접속했다`고 인식

# %% [markdown]
# - 이번에는 뉴스 제목을 크롤링해보고 제목을 단어단위로 분리해서 단어의 빈도수를 파악해보자.
# - 또한 상위단어를 워드 클라우드로 만들어보고 상위단어를 막대그래프로 그려보자.

# %% [markdown]
# - 워드 클라우드를 나타내기 위해 아래 모듈을 설치하자.

# %%
pip install wordcloud

# %% [markdown]
# - 아래 코드를 실행하다보면 버전이 낮아서 나오는 에러가 있다. 아래 코드를 실행하여 Pillow(이미지 처리 라이브러리) 모듈을 업그레이드 하자.

# %%
pip install --upgrade pillow

# %%
# %%writefile Ex_ch12_web2.py
import streamlit as st
import requests
from bs4 import BeautifulSoup
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import time
from matplotlib import rc, font_manager

font_path = "C:/Windows/Fonts/malgun.ttf"  # Windows 기준
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 페이지 제목
st.title("뉴스 트렌드 대시보드")
search = st.button("검색")

if search:
    st.write(f"검색 중...")
    
    # 네이버 뉴스 검색 URL
    url = f"https://news.naver.com/"
    
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36"
    }
    
    response = requests.get(url, headers=headers)
    time.sleep(1) 

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        # 뉴스 제목 추출
        news_items = soup.find_all(class_='cnf_news _cds_link _editn_link')
        #news_items = soup.select("a.news_tit")
        st.write(f"{len(news_items)}개 찾았습니다.")
        
        titles = [item.text for item in news_items[:20]]  # 상위 20개
        
        if titles:
            st.subheader("뉴스 기사 제목")
            for t in titles:
                st.write(f"- {t}")
            
            # 키워드 분석 (간단히 단어 빈도)
            words = []
            for t in titles:
                words += re.findall(r'[A-Za-z0-9]+|[가-힣]+', t)  # 단어 단위로 분리
            
            counter = Counter(words)
            most_common = dict(counter.most_common(50))  # 상위 50개
            # 워드클라우드 생성
            wc = WordCloud(
                width=800, 
                height=400, 
                font_path=font_path,
                background_color="white")

            wc.generate_from_frequencies(most_common)
            plt.figure(figsize=(8, 5)) 
            words_list = [w for w, _ in most_common.items()] 
            counts_list = [c for _, c in most_common.items()]

            # 막대그래프
            fig_bar, ax = plt.subplots(figsize=(8,5))
            ax.barh(words_list[:10:-1], counts_list[:10:-1])
            ax.set_title("상위 단어 빈도수", fontsize=14)
            ax.set_xlabel("빈도", fontsize=12)
            st.pyplot(fig_bar)

            # 워드클라우드
            fig_wc, ax = plt.subplots(figsize=(10,5))
            ax.imshow(wc, interpolation='bilinear')
            ax.axis("off")
            st.pyplot(fig_wc)
        else:
            st.write("뉴스 기사가 없습니다.")
    else:
        st.error("뉴스 검색 실패")
# Out:
# Overwriting Ex_ch12_web2.py

# %% [markdown]
# ## <div style="background-color:rgba(208, 205, 208, 1); padding: 10px; border-radius: 5px;"><mark style="background-color: rgba(208, 205, 208, 1);">**마무리**</mark></div>
# 오늘 수업에서는 BeautifulSoup을 활용하여 웹 페이지에서 필요한 정보를 추출하는 방법을 학습했다. 개발자도구를 활용하여 웹 페이지에서 필요한 정보를 추출하기 위한 태그와 속성 찾는 방법을 배웠으며, 또한 추출한 데이터를 분석하여 단어 빈도를 계산하고, 이를 WordCloud로 시각화하는 방법도 배웠다. 이 과정을 Streamlit과 연계하여, 사용자가 검색어를 입력하면 자동으로 해당 데이터를 크롤링하고, 기사 제목과 키워드 워드클라우드를 대시보드 형태로 확인할 수 있도록 구현해보았다. 이번 학습을 통해 웹 크롤링과 데이터 시각화가 어떻게 연결되는지 이해할 수 있었고, 단순한 데이터 수집을 넘어 시각적으로 정보를 표현하는 방법까지 경험했다. 앞으로는 이런 기술을 활용해 다양한 웹 데이터를 분석하고, 실시간 대시보드를 제작할 수 있을 것이다.

# %% [markdown]
# ---
# <font color='Grey' size="4">
# F37.206 컴퓨팅 탐색: 실생활에서 활용하기(Exploring Computing: Applications in Everyday Life)</font>
#
# ---
# 서울대학교 학부대학 강의교수 변해선
